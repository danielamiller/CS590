# %%
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
install.packages('nycflights13', repos = 'http://cran.us.r-project.org')
# Out:
# package 'nycflights13' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\gis\AppData\Local\Temp\RtmpATrG1P\downloaded_packages

# %%
library(nycflights13)
summary(flights)
# Out:
#       year          month             day           dep_time    sched_dep_time
#  Min.   :2013   Min.   : 1.000   Min.   : 1.00   Min.   :   1   Min.   : 106
#  1st Qu.:2013   1st Qu.: 4.000   1st Qu.: 8.00   1st Qu.: 907   1st Qu.: 906
#  Median :2013   Median : 7.000   Median :16.00   Median :1401   Median :1359
#  Mean   :2013   Mean   : 6.549   Mean   :15.71   Mean   :1349   Mean   :1344
#  3rd Qu.:2013   3rd Qu.:10.000   3rd Qu.:23.00   3rd Qu.:1744   3rd Qu.:1729
#  Max.   :2013   Max.   :12.000   Max.   :31.00   Max.   :2400   Max.   :2359
#                                                  NA's   :8255
#    dep_delay          arr_time    sched_arr_time   arr_delay
#  Min.   : -43.00   Min.   :   1   Min.   :   1   Min.   : -86.000
#  1st Qu.:  -5.00   1st Qu.:1104   1st Qu.:1124   1st Qu.: -17.000
#  Median :  -2.00   Median :1535   Median :1556   Median :  -5.000
#  Mean   :  12.64   Mean   :1502   Mean   :1536   Mean   :   6.895
# ...

# %%
dim(flights)
# Out:
# [1] 336776     19

# %%
head(filter(flights,month==11, day==3, carrier=='AA'))
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 11    3   538      545            -7        824      855
# 2 2013 11    3   556      600            -4        900      905
# 3 2013 11    3   604      610            -6        844      855
# 4 2013 11    3   624      629            -5        907      929
# 5 2013 11    3   625      630            -5        736      805
# 6 2013 11    3   653      655            -2        925      920
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 -31       AA      2243   N5DWAA  JFK    MIA  144      1089     5    45
# 2  -5       AA      1175   N3CSAA  LGA    MIA  148      1096     6     0
# 3 -11       AA      1103   N3KDAA  LGA    DFW  192      1389     6    10
# 4 -22       AA      1205   N3EJAA  EWR    MIA  141      1085     6    29
# 5 -29       AA       303   N4WJAA  LGA    ORD  113       733     6    30
# ...

# %%
flights[flights$month==11 & flights$day == 3 & flights$carrier == 'AA']
# Out:
# Length of logical index vector for `[` must equal number of columns (or 1):
# * `.data` has 19 columns
# * Index vector has length 336776Traceback:
#
# 1. flights[flights$month == 11 & flights$day == 3 & flights$carrier ==
#  .     "AA"]
# 2. `[.tbl_df`(flights, flights$month == 11 & flights$day == 3 &
#  .     flights$carrier == "AA")
# 3. check_names_df(i, x)
# 4. check_names_df_logical(j, x)
# 5. abort(error_mismatch_column_flag(length(x), length(j)))

# %%
slice(flights,1:10)
# Out:
#    year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1  2013 1     1   517      515             2         830      819
# 2  2013 1     1   533      529             4         850      830
# 3  2013 1     1   542      540             2         923      850
# 4  2013 1     1   544      545            -1        1004     1022
# 5  2013 1     1   554      600            -6         812      837
# 6  2013 1     1   554      558            -4         740      728
# 7  2013 1     1   555      600            -5         913      854
# 8  2013 1     1   557      600            -3         709      723
# 9  2013 1     1   557      600            -3         838      846
# 10 2013 1     1   558      600            -2         753      745
#    arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1   11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2   20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# ...

# %%
flights[1:10]
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
# 11     2013 1     1   558      600            -2         849      851
# 12     2013 1     1   558      600            -2         853      856
# ...

# %%
arrange(flights,year,month,day,air_time)
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   2302     2200            62       2342     2253
# 2      2013 1     1   1318     1322            -4       1358     1416
# 3      2013 1     1   2116     2110             6       2202     2212
# 4      2013 1     1   2000     2000             0       2054     2110
# 5      2013 1     1   2056     2004            52       2156     2112
# 6      2013 1     1    908      915            -7       1004     1033
# 7      2013 1     1   1315     1317            -2       1413     1423
# 8      2013 1     1   2030     2030             0       2132     2139
# 9      2013 1     1   1843     1845            -2       1955     2024
# 10     2013 1     1   2101     2050            11       2156     2202
# 11     2013 1     1   1600     1610           -10       1712     1729
# 12     2013 1     1   1607     1443            84       1711     1553
# ...

# %%
head(arrange(flights,desc(dep_delay)))
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1      9   641      900           1301      1242     1530
# 2 2013 6     15  1432     1935           1137      1607     2120
# 3 2013 1     10  1121     1635           1126      1239     1810
# 4 2013 9     20  1139     1845           1014      1457     2210
# 5 2013 7     22   845     1600           1005      1044     1815
# 6 2013 4     10  1100     1900            960      1342     2211
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 1272      HA        51   N384HA  JFK    HNL  640      4983      9    0
# 2 1127      MQ      3535   N504MQ  JFK    CMH   74       483     19   35
# 3 1109      MQ      3695   N517MQ  EWR    ORD  111       719     16   35
# 4 1007      AA       177   N338AA  JFK    SFO  354      2586     18   45
# 5  989      MQ      3075   N665MQ  JFK    CVG   96       589     16    0
# ...

# %%
head(arrange(flights,desc(dep_delay)))

# %%
carrierlevels=levels(as.factor(flights$carrier))
carrierlevels=relevel(
# Out:
#  [1] "9E" "AA" "AS" "B6" "DL" "EV" "F9" "FL" "HA" "MQ" "OO" "UA" "US" "VX" "WN"
# [16] "YV"

# %%
head(select(flights,carrier))
# Out:
#   carrier
# 1 UA
# 2 UA
# 3 AA
# 4 B6
# 5 DL
# 6 UA

# %%
head(select(flights,-carrier))
#everything except carrier
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay flight tailnum origin dest air_time distance hour minute
# 1  11       1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18        725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25        461   N668DN  LGA    ATL  116       762     6     0
# 6  12       1696   N39463  EWR    ORD  150       719     5    58
#   time_hour
# 1 2013-01-01 05:00:00
# ...

# %%
head(select(flights,carrier,origin))
# Out:
#   carrier origin
# 1 UA      EWR
# 2 UA      LGA
# 3 AA      JFK
# 4 B6      JFK
# 5 DL      LGA
# 6 UA      EWR

# %%
head(select(flights,carrier,origin,dest,everything()))
#puts the columns you want to be at beginning first, then lists rest in usual/undefined order
# Out:
#   carrier origin dest year month day dep_time sched_dep_time dep_delay arr_time
# 1 UA      EWR    IAH  2013 1     1   517      515             2         830
# 2 UA      LGA    IAH  2013 1     1   533      529             4         850
# 3 AA      JFK    MIA  2013 1     1   542      540             2         923
# 4 B6      JFK    BQN  2013 1     1   544      545            -1        1004
# 5 DL      LGA    ATL  2013 1     1   554      600            -6         812
# 6 UA      EWR    ORD  2013 1     1   554      558            -4         740
#   sched_arr_time arr_delay flight tailnum air_time distance hour minute
# 1  819            11       1545   N14228  227      1400     5    15
# 2  830            20       1714   N24211  227      1416     5    29
# 3  850            33       1141   N619AA  160      1089     5    40
# 4 1022           -18        725   N804JB  183      1576     5    45
# 5  837           -25        461   N668DN  116       762     6     0
# ...

# %%
head(rename(flights,airline_car = carrier))
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay airline_car flight tailnum origin dest air_time distance hour
# 1  11       UA          1545   N14228  EWR    IAH  227      1400     5
# 2  20       UA          1714   N24211  LGA    IAH  227      1416     5
# 3  33       AA          1141   N619AA  JFK    MIA  160      1089     5
# 4 -18       B6           725   N804JB  JFK    BQN  183      1576     5
# 5 -25       DL           461   N668DN  LGA    ATL  116       762     6
# 6  12       UA          1696   N39463  EWR    ORD  150       719     5
# ...

# %%
distinct(select(flights,carrier))
#find and list unique values of column
#same as unique in base-R unique(flights$carrier)
# Out:
#    carrier
# 1  UA
# 2  AA
# 3  B6
# 4  DL
# 5  EV
# 6  MQ
# 7  US
# 8  WN
# 9  VX
# 10 FL
# 11 AS
# 12 9E
# 13 F9
# 14 HA
# 15 YV
# 16 OO

# %%
#add new columns that are functions of other columns
head(mutate(flights,new_col=arr_delay-dep_delay)) %>% select(carrier, new_col, everything())
#when you pipe, don't need to tell which dataset to use (uses the one from previous step in pipe)
# Out:
#   carrier new_col year month day dep_time sched_dep_time dep_delay arr_time
# 1 UA        9     2013 1     1   517      515             2         830
# 2 UA       16     2013 1     1   533      529             4         850
# 3 AA       31     2013 1     1   542      540             2         923
# 4 B6      -17     2013 1     1   544      545            -1        1004
# 5 DL      -19     2013 1     1   554      600            -6         812
# 6 UA       16     2013 1     1   554      558            -4         740
#   sched_arr_time arr_delay flight tailnum origin dest air_time distance hour
# 1  819            11       1545   N14228  EWR    IAH  227      1400     5
# 2  830            20       1714   N24211  LGA    IAH  227      1416     5
# 3  850            33       1141   N619AA  JFK    MIA  160      1089     5
# 4 1022           -18        725   N804JB  JFK    BQN  183      1576     5
# 5  837           -25        461   N668DN  LGA    ATL  116       762     6
# ...

# %%
#please don't use -- gets rid of all columns except the new one
head(transmute(flights, new_col = arr_delay-dep_delay))
# Out:
#   new_col
# 1   9
# 2  16
# 3  31
# 4 -17
# 5 -19
# 6  16

# %%
summarise(flights,avg_air_time = mean(air_time, na.rm=TRUE))
# Out:
#   avg_air_time
# 1 150.6865

# %%
#define random number for following code to take a random sample from
set.seed(10)
sample_n(flights,10)
# Out:
#    year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1  2013  3    17   755      800           -5         943     1004
# 2  2013 12    31  1430     1432           -2        1546     1555
# 3  2013  5    20  1157     1115           42        1428     1410
# 4  2013  4     4   921      930           -9        1237     1244
# 5  2013 12    12   828      830           -2        1032     1037
# 6  2013 11    30  1614     1615           -1        1833     1852
# 7  2013  3    12  1135     1140           -5        1427     1445
# 8  2013 12     6  2011     1900           71        2202     2035
# 9  2013  7    19  1939     1830           69        2048     1955
# 10 2013 11     4  1414     1414            0        1536     1534
#    arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  -21       B6      1273   N258JB  JFK    CHS   94       636      8    0
# 2   -9       YV      3771   N515MJ  LGA    IAD   52       229     14   32
# ...

# %%
sample_frac(flights,0.00005)
#use replace=TRUE for bootstrap sampling
# Out:
#    year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1  2013  2    24  2032     2040            -8       2230     2237
# 2  2013 12     1  1140     1145            -5       1415     1433
# 3  2013 12    18  1529     1438            51       1624     1541
# 4  2013  4    22  2126     1935           111       2239     2100
# 5  2013  7    15  1711     1710             1       1848     1905
# 6  2013  2    15   933      940            -7       1303     1250
# 7  2013 12    11    NA      645            NA         NA      857
# 8  2013 10     9   754      759            -5        850      906
# 9  2013  9    15   822      825            -3       1028     1022
# 10 2013  2     8   728      705            23       1052     1035
# 11 2013 12     5  1325     1310            15       1612     1607
# 12 2013  4     4   700      700             0        950      947
# 13 2013  5    19    NA     2120            NA         NA     2300
# ...

# %%
#tidyr() package
#helps you create "tidy" data
#tidy means each variable is its own column; each observation is its own row
install.packages('tidyr', repos = 'http://cran.us.r-project.org')
# Out:
# also installing the dependencies 'rlang', 'dplyr'
#
# Warning message:
# "package 'dplyr' is in use and will not be installed"
# package 'rlang' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'rlang'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\gis\AppData\Local\Continuum\anaconda3\Lib\R\library\00LOCK\rlang\libs\x64\rlang.dll to C:\Users\gis\AppData\Local\Continuum\anaconda3\Lib\R\library\rlang\libs\x64\rlang.dll: Permission denied"Warning message:
# "restored 'rlang'"
# package 'tidyr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\gis\AppData\Local\Temp\RtmpATrG1P\downloaded_packages

# %%
# Out:
# Error in detach(dplyr): invalid 'name' argument
# Traceback:
#
# 1. detach(dplyr)
# 2. stop("invalid 'name' argument")

# %%
library('tidyr')
# Out:
# Error: package or namespace load failed for 'tidyr' in loadNamespace(i, c(lib.loc, .libPaths()), versionCheck = vI[[i]]):
#  namespace 'rlang' 0.3.4 is already loaded, but >= 0.4.0 is required
# Traceback:
#
# 1. library("tidyr")
# 2. tryCatch({
#  .     attr(package, "LibPath") <- which.lib.loc
#  .     ns <- loadNamespace(package, lib.loc)
#  .     env <- attachNamespace(ns, pos = pos, deps, exclude, include.only)
#  . }, error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste(" in", deparse(cc)[1L])
#  .     else ""
#  .     msg <- gettextf("package or namespace load failed for %s%s:\n %s",
#  .         sQuote(package), P, conditionMessage(e))
#  .     if (logical.return)
#  .         message(paste("Error:", msg), domain = NA)
#  .     else stop(msg, call. = FALSE, domain = NA)
#  . })
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. value[[3L]](cond)
# ...
