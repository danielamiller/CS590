# %% [markdown]
# ![](logo.png)

# %% [markdown]
# # <font color='red'>Introduction to Pandas Exercise</font>
#
# The last two weeks focused on the Pandas library, specifically input of files to dataframes, indexing a selecting subsets of data, merging and joining, and output of dataframes to various files. This exercise is designed to review the materials coverd in the Week 4 and 5 lectures.

# %% [markdown]
# 1. Import Pandas, Numpy and OS libraries

# %%
import pandas
import numpy
import os

# %% [markdown]
# 2. Read in the peanut_lines CSV file as **peanut_lines** (Use encoding='ISO-8859-1')

# %%
os.getcwd()
peanut_lines = pandas.read_csv('peanut_lines.csv', encoding='ISO-8859-1')
peanut_lines
# Out:
#       NC_Accession                              Identity or Parentage  \
# 0    ACI WT09-0761                                      ACI WT09-0761
# 1    ACI WT11-0351                                      ACI WT11-0351
# 2    ACI WT12-0226                                      ACI WT12-0226
# 3    ACI WT12-0419                                      ACI WT12-0419
# 4    ACI WT12-0420                                      ACI WT12-0420
# 5    ACI WT12-0433                                      ACI WT12-0433
# 6           Bailey                                 NC 12C*2 / N96076L
# 7        Bailey II  Bailey /4/ X07016, Bailey // X05027, Bailey / ...
# 8         Brantley                                           Brantley
# 9           CHAMPS                                             CHAMPS
# 10           Emery                              N03079FT*2 / Brantley
# 11   Florida Fancy                                      Florida Fancy
# 12      Florida-07                                         Florida-07
# 13      FloriGiant                                         FloriGiant
# 14      FloRun 107                                         FloRun 107
# 15      FloRun 157                                         FloRun 157
# 16      FloRun 331                                         FloRun 331
# 17   Georgia Green                                      Georgia Green
# 18     Georgia-06G                                        Georgia-06G
# 19     Georgia-07W                                        Georgia-07W
# 20     Georgia-09B                                        Georgia-09B
# 21     Georgia-11J                                        Georgia-11J
# 22     Georgia-12Y                                        Georgia-12Y
# 23         Gregory                                            Gregory
# 24        Harris 1                                           Harris 1
# 25       HTS 02-06                              NC Ac 18000 / 9548-10
# 26     HTS 15-04ol                SPT 06-07 // N03079FT*2 / N02054ol
# 27          N03088                                 NC 12C*2 / N96076L
# 28          N04067                                    N96029 / N97069
# 29          N04072                                    N96029 / N97069
# ..             ...                                                ...
# 829            NaN                                                NaN
# 830            NaN                                                NaN
# 831            NaN                                                NaN
# 832            NaN                                                NaN
# 833            NaN                                                NaN
# 834            NaN                                                NaN
# 835            NaN                                                NaN
# 836            NaN                                                NaN
# 837            NaN                                                NaN
# 838            NaN                                                NaN
# 839            NaN                                                NaN
# 840            NaN                                                NaN
# 841            NaN                                                NaN
# 842            NaN                                                NaN
# 843            NaN                                                NaN
# 844            NaN                                                NaN
# 845            NaN                                                NaN
# 846            NaN                                                NaN
# 847            NaN                                                NaN
# 848            NaN                                                NaN
# 849            NaN                                                NaN
# 850            NaN                                                NaN
# 851            NaN                                                NaN
# 852            NaN                                                NaN
# 853            NaN                                                NaN
# 854            NaN                                                NaN
# 855            NaN                                                NaN
# 856            NaN                                                NaN
# 857            NaN                                                NaN
# 858            NaN                                                NaN
#
#                          Pedigree    FAG
# 0                             NaN  Check
# 1                             NaN  ol ol
# 2                             NaN  ol ol
# 3                             NaN  Check
# 4                             NaN  ol ol
# 5                             NaN  Check
# 6      BC1F1-06-01-S-03-S-05: F09    + +
# 7      BC3F1-02-01-S-02-S-02: F09  ol ol
# 8                             NaN  ol ol
# 9                             NaN    + +
# 10   BC1F1-03-01-01-02-02-01: F08  ol ol
# 11                            NaN  ol ol
# 12                            NaN  ol ol
# 13                            NaN    + +
# 14                            NaN  ol ol
# 15                            NaN  ol ol
# 16                            NaN  ol ol
# 17                            NaN    + +
# 18                            NaN    + +
# 19                            NaN    + +
# 20                            NaN  ol ol
# 21                            NaN  ol ol
# 22                            NaN    + +
# 23                            NaN    + +
# 24                            NaN  Check
# 25                            NaN    + +
# 26                            NaN  ol ol
# 27     BC1F1-06-04-S-02-S-08: F09    + +
# 28           F2-03-S-01-S-06: F09    + +
# 29           F2-03-S-03-S-03: F09    + +
# ..                            ...    ...
# 829                           NaN    NaN
# 830                           NaN    NaN
# 831                           NaN    NaN
# 832                           NaN    NaN
# 833                           NaN    NaN
# 834                           NaN    NaN
# 835                           NaN    NaN
# 836                           NaN    NaN
# 837                           NaN    NaN
# 838                           NaN    NaN
# 839                           NaN    NaN
# 840                           NaN    NaN
# 841                           NaN    NaN
# 842                           NaN    NaN
# 843                           NaN    NaN
# 844                           NaN    NaN
# 845                           NaN    NaN
# 846                           NaN    NaN
# 847                           NaN    NaN
# 848                           NaN    NaN
# 849                           NaN    NaN
# 850                           NaN    NaN
# 851                           NaN    NaN
# 852                           NaN    NaN
# 853                           NaN    NaN
# 854                           NaN    NaN
# 855                           NaN    NaN
# 856                           NaN    NaN
# 857                           NaN    NaN
# 858                           NaN    NaN
#
# [859 rows x 4 columns]

# %% [markdown]
# 3. Check the head of the files

# %%
peanut_lines.head()
# Out:
#     NC_Accession Identity or Parentage Pedigree    FAG
# 0  ACI WT09-0761         ACI WT09-0761      NaN  Check
# 1  ACI WT11-0351         ACI WT11-0351      NaN  ol ol
# 2  ACI WT12-0226         ACI WT12-0226      NaN  ol ol
# 3  ACI WT12-0419         ACI WT12-0419      NaN  Check
# 4  ACI WT12-0420         ACI WT12-0420      NaN  ol ol

# %% [markdown]
# 4. Use the .info() method to find out how many peanut_lines are in the dataframe
#
#     **Bonus: Print the total number of entries?

# %%
peanut_lines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 859 entries, 0 to 858
# Data columns (total 4 columns):
# NC_Accession             466 non-null object
# Identity or Parentage    466 non-null object
# Pedigree                 409 non-null object
# FAG                      466 non-null object
# dtypes: object(4)
# memory usage: 26.9+ KB

# %% [markdown]
# 5. Read in the peanut_yield text file as **peanut_yield** (Use encoding='ISO-8859-1')

# %%
peanut_yield = pandas.read_csv('peanut_yield.txt', sep='\t', encoding='ISO-8859-1')
peanut_yield
# Out:
#       Year Location Name                             Label   NC_Accession  \
# 0     2014      LEW  ATP  Advanced Testing Program - Yield  ACI WT09-0761
# 1     2014      RMT  ATP  Advanced Testing Program - Yield  ACI WT09-0761
# 2     2014      WHI  ATP  Advanced Testing Program - Yield  ACI WT09-0761
# 3     2015      LEW  ATP  Advanced Testing Program - Yield  ACI WT11-0351
# 4     2015      RMT  ATP  Advanced Testing Program - Yield  ACI WT11-0351
# 5     2015      LEW  ATP  Advanced Testing Program - Yield  ACI WT12-0226
# 6     2015      RMT  ATP  Advanced Testing Program - Yield  ACI WT12-0226
# 7     2014      LEW  ATP  Advanced Testing Program - Yield  ACI WT12-0419
# 8     2014      RMT  ATP  Advanced Testing Program - Yield  ACI WT12-0419
# 9     2014      WHI  ATP  Advanced Testing Program - Yield  ACI WT12-0419
# 10    2015      LEW  ATP  Advanced Testing Program - Yield  ACI WT12-0420
# 11    2015      RMT  ATP  Advanced Testing Program - Yield  ACI WT12-0420
# 12    2014      LEW  ATP  Advanced Testing Program - Yield  ACI WT12-0433
# 13    2014      RMT  ATP  Advanced Testing Program - Yield  ACI WT12-0433
# 14    2014      WHI  ATP  Advanced Testing Program - Yield  ACI WT12-0433
# 15    2010      LEW  ATP  Advanced Testing Program - Yield         Bailey
# 16    2010      RMT  ATP  Advanced Testing Program - Yield         Bailey
# 17    2010      WHI  ATP  Advanced Testing Program - Yield         Bailey
# 18    2011      LEW  ATP  Advanced Testing Program - Yield         Bailey
# 19    2011      RMT  ATP  Advanced Testing Program - Yield         Bailey
# 20    2011      WHI  ATP  Advanced Testing Program - Yield         Bailey
# 21    2012      LEW  ATP  Advanced Testing Program - Yield         Bailey
# 22    2012      RMT  ATP  Advanced Testing Program - Yield         Bailey
# 23    2012      WHI  ATP  Advanced Testing Program - Yield         Bailey
# 24    2013      LEW  ATP  Advanced Testing Program - Yield         Bailey
# 25    2013      RMT  ATP  Advanced Testing Program - Yield         Bailey
# 26    2013      WHI  ATP  Advanced Testing Program - Yield         Bailey
# 27    2014      LEW  ATP  Advanced Testing Program - Yield         Bailey
# 28    2014      RMT  ATP  Advanced Testing Program - Yield         Bailey
# 29    2014      WHI  ATP  Advanced Testing Program - Yield         Bailey
# ...    ...      ...  ...                               ...            ...
# 2603  2015      RMT  ATP  Advanced Testing Program - Yield  TUFRunner 727
# 2604  2010      LEW  ATP  Advanced Testing Program - Yield         VA 98R
# 2605  2010      RMT  ATP  Advanced Testing Program - Yield         VA 98R
# 2606  2010      WHI  ATP  Advanced Testing Program - Yield         VA 98R
# 2607  2010      LEW  ATP  Advanced Testing Program - Yield          Wynne
# 2608  2010      RMT  ATP  Advanced Testing Program - Yield          Wynne
# 2609  2010      WHI  ATP  Advanced Testing Program - Yield          Wynne
# 2610  2011      LEW  ATP  Advanced Testing Program - Yield          Wynne
# 2611  2011      RMT  ATP  Advanced Testing Program - Yield          Wynne
# 2612  2011      WHI  ATP  Advanced Testing Program - Yield          Wynne
# 2613  2012      LEW  ATP  Advanced Testing Program - Yield          Wynne
# 2614  2012      RMT  ATP  Advanced Testing Program - Yield          Wynne
# 2615  2012      WHI  ATP  Advanced Testing Program - Yield          Wynne
# 2616  2013      LEW  ATP  Advanced Testing Program - Yield          Wynne
# 2617  2013      RMT  ATP  Advanced Testing Program - Yield          Wynne
# 2618  2013      WHI  ATP  Advanced Testing Program - Yield          Wynne
# 2619  2014      LEW  ATP  Advanced Testing Program - Yield          Wynne
# 2620  2014      RMT  ATP  Advanced Testing Program - Yield          Wynne
# 2621  2014      WHI  ATP  Advanced Testing Program - Yield          Wynne
# 2622  2015      LEW  ATP  Advanced Testing Program - Yield          Wynne
# 2623  2015      RMT  ATP  Advanced Testing Program - Yield          Wynne
# 2624  2016      LEW  ATP  Advanced Testing Program - Yield          Wynne
# 2625  2016      RMT  ATP  Advanced Testing Program - Yield          Wynne
# 2626  2016      WHI  ATP  Advanced Testing Program - Yield          Wynne
# 2627  2017      LEW  ATP  Advanced Testing Program - Yield          Wynne
# 2628  2017      RMT  ATP  Advanced Testing Program - Yield          Wynne
# 2629  2017      WHI  ATP  Advanced Testing Program - Yield          Wynne
# 2630  2018      LEW  ATP  Advanced Testing Program - Yield          Wynne
# 2631  2018      RMT  ATP  Advanced Testing Program - Yield          Wynne
# 2632  2018      WHI  ATP  Advanced Testing Program - Yield          Wynne
#
#       Plot_Yield  Yield
# 0            9.0   2733
# 1           10.2   3085
# 2           10.2   3085
# 3           15.3   4632
# 4           10.7   3226
# 5           13.6   4104
# 6           15.1   4572
# 7            6.6   1993
# 8            8.1   2457
# 9            8.1   2457
# 10          11.3   3414
# 11          16.3   4932
# 12          12.2   3687
# 13          11.0   3316
# 14          11.0   3316
# 15          11.7   3529
# 16           6.6   2004
# 17           6.1   1860
# 18          13.6   4114
# 19          17.1   5159
# 20          11.1   3345
# 21          12.8   3873
# 22          10.9   3306
# 23          16.3   4927
# 24          12.5   3774
# 25          12.5   3781
# 26           8.0   2418
# 27          16.3   4926
# 28          12.1   3660
# 29          12.1   3660
# ...          ...    ...
# 2603        10.2   3093
# 2604        10.6   3213
# 2605         6.3   1906
# 2606         6.0   1815
# 2607        10.2   3099
# 2608         6.5   1966
# 2609         6.6   1989
# 2610        14.5   4394
# 2611        17.3   5235
# 2612         8.8   2670
# 2613        12.7   3849
# 2614         9.0   2734
# 2615        15.2   4613
# 2616        10.8   3275
# 2617         9.2   2798
# 2618         8.6   2596
# 2619        17.2   5203
# 2620        11.5   3478
# 2621        11.5   3478
# 2622        15.9   4814
# 2623        19.2   5795
# 2624        10.1   3044
# 2625         9.7   2934
# 2626         9.1   2741
# 2627        17.6   5320
# 2628        20.2   6102
# 2629         4.9   1495
# 2630        17.3   5244
# 2631        14.4   4370
# 2632        20.2   6125
#
# [2633 rows x 7 columns]

# %% [markdown]
# 6. Check the column names of peanut_yield

# %%
peanut_yield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2633 entries, 0 to 2632
# Data columns (total 7 columns):
# Year            2633 non-null int64
# Location        2633 non-null object
# Name            2633 non-null object
# Label           2633 non-null object
# NC_Accession    2633 non-null object
# Plot_Yield      2633 non-null float64
# Yield           2633 non-null int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 144.1+ KB

# %% [markdown]
# 7. Using 'NC_Accession', merge (or join) the two dataframes together keeping the entirety of the peanut_yield data. Name the new dataframe **peanut_data**

# %%
peanut_data = pandas.merge(peanut_lines, peanut_yield, how='outer', on='NC_Accession')
peanut_data
# Out:
#        NC_Accession Identity or Parentage                    Pedigree    FAG  \
# 0     ACI WT09-0761         ACI WT09-0761                         NaN  Check
# 1     ACI WT09-0761         ACI WT09-0761                         NaN  Check
# 2     ACI WT09-0761         ACI WT09-0761                         NaN  Check
# 3     ACI WT11-0351         ACI WT11-0351                         NaN  ol ol
# 4     ACI WT11-0351         ACI WT11-0351                         NaN  ol ol
# 5     ACI WT12-0226         ACI WT12-0226                         NaN  ol ol
# 6     ACI WT12-0226         ACI WT12-0226                         NaN  ol ol
# 7     ACI WT12-0419         ACI WT12-0419                         NaN  Check
# 8     ACI WT12-0419         ACI WT12-0419                         NaN  Check
# 9     ACI WT12-0419         ACI WT12-0419                         NaN  Check
# 10    ACI WT12-0420         ACI WT12-0420                         NaN  ol ol
# 11    ACI WT12-0420         ACI WT12-0420                         NaN  ol ol
# 12    ACI WT12-0433         ACI WT12-0433                         NaN  Check
# 13    ACI WT12-0433         ACI WT12-0433                         NaN  Check
# 14    ACI WT12-0433         ACI WT12-0433                         NaN  Check
# 15           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 16           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 17           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 18           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 19           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 20           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 21           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 22           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 23           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 24           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 25           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 26           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 27           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 28           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 29           Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# ...             ...                   ...                         ...    ...
# 3029            NaN                   NaN                         NaN    NaN
# 3030            NaN                   NaN                         NaN    NaN
# 3031            NaN                   NaN                         NaN    NaN
# 3032            NaN                   NaN                         NaN    NaN
# 3033            NaN                   NaN                         NaN    NaN
# 3034            NaN                   NaN                         NaN    NaN
# 3035            NaN                   NaN                         NaN    NaN
# 3036            NaN                   NaN                         NaN    NaN
# 3037            NaN                   NaN                         NaN    NaN
# 3038            NaN                   NaN                         NaN    NaN
# 3039            NaN                   NaN                         NaN    NaN
# 3040            NaN                   NaN                         NaN    NaN
# 3041            NaN                   NaN                         NaN    NaN
# 3042            NaN                   NaN                         NaN    NaN
# 3043            NaN                   NaN                         NaN    NaN
# 3044            NaN                   NaN                         NaN    NaN
# 3045            NaN                   NaN                         NaN    NaN
# 3046            NaN                   NaN                         NaN    NaN
# 3047            NaN                   NaN                         NaN    NaN
# 3048            NaN                   NaN                         NaN    NaN
# 3049            NaN                   NaN                         NaN    NaN
# 3050            NaN                   NaN                         NaN    NaN
# 3051            NaN                   NaN                         NaN    NaN
# 3052            NaN                   NaN                         NaN    NaN
# 3053            NaN                   NaN                         NaN    NaN
# 3054       Tifguard                   NaN                         NaN    NaN
# 3055       Tifguard                   NaN                         NaN    NaN
# 3056       Tifguard                   NaN                         NaN    NaN
# 3057       Tifguard                   NaN                         NaN    NaN
# 3058       Tifguard                   NaN                         NaN    NaN
#
#         Year Location Name                             Label  Plot_Yield  \
# 0     2014.0      LEW  ATP  Advanced Testing Program - Yield         9.0
# 1     2014.0      RMT  ATP  Advanced Testing Program - Yield        10.2
# 2     2014.0      WHI  ATP  Advanced Testing Program - Yield        10.2
# 3     2015.0      LEW  ATP  Advanced Testing Program - Yield        15.3
# 4     2015.0      RMT  ATP  Advanced Testing Program - Yield        10.7
# 5     2015.0      LEW  ATP  Advanced Testing Program - Yield        13.6
# 6     2015.0      RMT  ATP  Advanced Testing Program - Yield        15.1
# 7     2014.0      LEW  ATP  Advanced Testing Program - Yield         6.6
# 8     2014.0      RMT  ATP  Advanced Testing Program - Yield         8.1
# 9     2014.0      WHI  ATP  Advanced Testing Program - Yield         8.1
# 10    2015.0      LEW  ATP  Advanced Testing Program - Yield        11.3
# 11    2015.0      RMT  ATP  Advanced Testing Program - Yield        16.3
# 12    2014.0      LEW  ATP  Advanced Testing Program - Yield        12.2
# 13    2014.0      RMT  ATP  Advanced Testing Program - Yield        11.0
# 14    2014.0      WHI  ATP  Advanced Testing Program - Yield        11.0
# 15    2010.0      LEW  ATP  Advanced Testing Program - Yield        11.7
# 16    2010.0      RMT  ATP  Advanced Testing Program - Yield         6.6
# 17    2010.0      WHI  ATP  Advanced Testing Program - Yield         6.1
# 18    2011.0      LEW  ATP  Advanced Testing Program - Yield        13.6
# 19    2011.0      RMT  ATP  Advanced Testing Program - Yield        17.1
# 20    2011.0      WHI  ATP  Advanced Testing Program - Yield        11.1
# 21    2012.0      LEW  ATP  Advanced Testing Program - Yield        12.8
# 22    2012.0      RMT  ATP  Advanced Testing Program - Yield        10.9
# 23    2012.0      WHI  ATP  Advanced Testing Program - Yield        16.3
# 24    2013.0      LEW  ATP  Advanced Testing Program - Yield        12.5
# 25    2013.0      RMT  ATP  Advanced Testing Program - Yield        12.5
# 26    2013.0      WHI  ATP  Advanced Testing Program - Yield         8.0
# 27    2014.0      LEW  ATP  Advanced Testing Program - Yield        16.3
# 28    2014.0      RMT  ATP  Advanced Testing Program - Yield        12.1
# 29    2014.0      WHI  ATP  Advanced Testing Program - Yield        12.1
# ...      ...      ...  ...                               ...         ...
# 3029     NaN      NaN  NaN                               NaN         NaN
# 3030     NaN      NaN  NaN                               NaN         NaN
# 3031     NaN      NaN  NaN                               NaN         NaN
# 3032     NaN      NaN  NaN                               NaN         NaN
# 3033     NaN      NaN  NaN                               NaN         NaN
# 3034     NaN      NaN  NaN                               NaN         NaN
# 3035     NaN      NaN  NaN                               NaN         NaN
# 3036     NaN      NaN  NaN                               NaN         NaN
# 3037     NaN      NaN  NaN                               NaN         NaN
# 3038     NaN      NaN  NaN                               NaN         NaN
# 3039     NaN      NaN  NaN                               NaN         NaN
# 3040     NaN      NaN  NaN                               NaN         NaN
# 3041     NaN      NaN  NaN                               NaN         NaN
# 3042     NaN      NaN  NaN                               NaN         NaN
# 3043     NaN      NaN  NaN                               NaN         NaN
# 3044     NaN      NaN  NaN                               NaN         NaN
# 3045     NaN      NaN  NaN                               NaN         NaN
# 3046     NaN      NaN  NaN                               NaN         NaN
# 3047     NaN      NaN  NaN                               NaN         NaN
# 3048     NaN      NaN  NaN                               NaN         NaN
# 3049     NaN      NaN  NaN                               NaN         NaN
# 3050     NaN      NaN  NaN                               NaN         NaN
# 3051     NaN      NaN  NaN                               NaN         NaN
# 3052     NaN      NaN  NaN                               NaN         NaN
# 3053     NaN      NaN  NaN                               NaN         NaN
# 3054  2015.0      LEW  ATP  Advanced Testing Program - Yield        14.3
# 3055  2015.0      RMT  ATP  Advanced Testing Program - Yield        12.8
# 3056  2016.0      LEW  ATP  Advanced Testing Program - Yield         9.5
# 3057  2016.0      RMT  ATP  Advanced Testing Program - Yield         8.6
# 3058  2016.0      WHI  ATP  Advanced Testing Program - Yield         9.5
#
#        Yield
# 0     2733.0
# 1     3085.0
# 2     3085.0
# 3     4632.0
# 4     3226.0
# 5     4104.0
# 6     4572.0
# 7     1993.0
# 8     2457.0
# 9     2457.0
# 10    3414.0
# 11    4932.0
# 12    3687.0
# 13    3316.0
# 14    3316.0
# 15    3529.0
# 16    2004.0
# 17    1860.0
# 18    4114.0
# 19    5159.0
# 20    3345.0
# 21    3873.0
# 22    3306.0
# 23    4927.0
# 24    3774.0
# 25    3781.0
# 26    2418.0
# 27    4926.0
# 28    3660.0
# 29    3660.0
# ...      ...
# 3029     NaN
# 3030     NaN
# 3031     NaN
# 3032     NaN
# 3033     NaN
# 3034     NaN
# 3035     NaN
# 3036     NaN
# 3037     NaN
# 3038     NaN
# 3039     NaN
# 3040     NaN
# 3041     NaN
# 3042     NaN
# 3043     NaN
# 3044     NaN
# 3045     NaN
# 3046     NaN
# 3047     NaN
# 3048     NaN
# 3049     NaN
# 3050     NaN
# 3051     NaN
# 3052     NaN
# 3053     NaN
# 3054  4312.0
# 3055  3869.0
# 3056  2884.0
# 3057  2609.0
# 3058  2869.0
#
# [3059 rows x 10 columns]

# %% [markdown]
# 8. What is the average yield in 2017?

# %%
peanut_yield[(peanut_yield['Year'] == 2017)]['Yield'].mean()
# Out:
# 3981.6

# %% [markdown]
# 9. What was the aveerage yield of the top 10 lines tested in the peanut program?

# %%
peanut_yield.iloc[0:10]['Yield'].mean()
# Out:
# 3234.4

# %% [markdown]
# 10. What are the top 10 most commonly tested lines? Hint: value_counts()

# %%
test_counts = peanut_yield['NC_Accession'].value_counts()
ordered_test_counts = test_counts.sort_values()
ordered_test_counts[-11:-1]
# Out:
# N10078        17
# N13003        17
# Gregory       18
# N11020        20
# Florida-07    20
# Bailey II     20
# Bailey        26
# Emery         26
# Sugg          26
# Sullivan      26
# Name: NC_Accession, dtype: int64

# %% [markdown]
# 11. Create a dataframe that satisfy the following requirements
# <br>peanut lines = 'Bailey', 'Sullivan', 'Wynne', 'Emery', 'Bailey II', 'N14023'
# <br>location = 'LEW', 'RMT' #Lewiston and Rocky Mount
# <br>Dataframe = line_data

# %%
#peanut_yield[(peanut_yield['NC_Accession'] == 'Bailey')][(peanut_yield['Location'] == 'LEW')]
locations = ['LEW', 'RMT']
accessions = ['Bailey', 'Sullivan', 'Wynne', 'Emery', 'Bailey II', 'N14023']
line_data = pandas.DataFrame(peanut_yield[peanut_yield.Location.isin(locations)][peanut_yield.NC_Accession.isin(accessions)])
line_data
# Out:
# C:\Users\Daniela\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#       Year Location Name                             Label NC_Accession  \
# 15    2010      LEW  ATP  Advanced Testing Program - Yield       Bailey
# 16    2010      RMT  ATP  Advanced Testing Program - Yield       Bailey
# 18    2011      LEW  ATP  Advanced Testing Program - Yield       Bailey
# 19    2011      RMT  ATP  Advanced Testing Program - Yield       Bailey
# 21    2012      LEW  ATP  Advanced Testing Program - Yield       Bailey
# 22    2012      RMT  ATP  Advanced Testing Program - Yield       Bailey
# 24    2013      LEW  ATP  Advanced Testing Program - Yield       Bailey
# 25    2013      RMT  ATP  Advanced Testing Program - Yield       Bailey
# 27    2014      LEW  ATP  Advanced Testing Program - Yield       Bailey
# 28    2014      RMT  ATP  Advanced Testing Program - Yield       Bailey
# 30    2015      LEW  ATP  Advanced Testing Program - Yield       Bailey
# 31    2015      RMT  ATP  Advanced Testing Program - Yield       Bailey
# 32    2016      LEW  ATP  Advanced Testing Program - Yield       Bailey
# 33    2016      RMT  ATP  Advanced Testing Program - Yield       Bailey
# 35    2017      LEW  ATP  Advanced Testing Program - Yield       Bailey
# 36    2017      RMT  ATP  Advanced Testing Program - Yield       Bailey
# 38    2018      LEW  ATP  Advanced Testing Program - Yield       Bailey
# 39    2018      RMT  ATP  Advanced Testing Program - Yield       Bailey
# 41    2012      LEW  ATP  Advanced Testing Program - Yield    Bailey II
# 42    2012      RMT  ATP  Advanced Testing Program - Yield    Bailey II
# 44    2013      LEW  ATP  Advanced Testing Program - Yield    Bailey II
# 45    2013      RMT  ATP  Advanced Testing Program - Yield    Bailey II
# 47    2014      LEW  ATP  Advanced Testing Program - Yield    Bailey II
# 48    2014      RMT  ATP  Advanced Testing Program - Yield    Bailey II
# 50    2015      LEW  ATP  Advanced Testing Program - Yield    Bailey II
# 51    2015      RMT  ATP  Advanced Testing Program - Yield    Bailey II
# 52    2016      LEW  ATP  Advanced Testing Program - Yield    Bailey II
# 53    2016      RMT  ATP  Advanced Testing Program - Yield    Bailey II
# 55    2017      LEW  ATP  Advanced Testing Program - Yield    Bailey II
# 56    2017      RMT  ATP  Advanced Testing Program - Yield    Bailey II
# ...    ...      ...  ...                               ...          ...
# 2557  2013      LEW  ATP  Advanced Testing Program - Yield     Sullivan
# 2558  2013      RMT  ATP  Advanced Testing Program - Yield     Sullivan
# 2560  2014      LEW  ATP  Advanced Testing Program - Yield     Sullivan
# 2561  2014      RMT  ATP  Advanced Testing Program - Yield     Sullivan
# 2563  2015      LEW  ATP  Advanced Testing Program - Yield     Sullivan
# 2564  2015      RMT  ATP  Advanced Testing Program - Yield     Sullivan
# 2565  2016      LEW  ATP  Advanced Testing Program - Yield     Sullivan
# 2566  2016      RMT  ATP  Advanced Testing Program - Yield     Sullivan
# 2568  2017      LEW  ATP  Advanced Testing Program - Yield     Sullivan
# 2569  2017      RMT  ATP  Advanced Testing Program - Yield     Sullivan
# 2571  2018      LEW  ATP  Advanced Testing Program - Yield     Sullivan
# 2572  2018      RMT  ATP  Advanced Testing Program - Yield     Sullivan
# 2607  2010      LEW  ATP  Advanced Testing Program - Yield        Wynne
# 2608  2010      RMT  ATP  Advanced Testing Program - Yield        Wynne
# 2610  2011      LEW  ATP  Advanced Testing Program - Yield        Wynne
# 2611  2011      RMT  ATP  Advanced Testing Program - Yield        Wynne
# 2613  2012      LEW  ATP  Advanced Testing Program - Yield        Wynne
# 2614  2012      RMT  ATP  Advanced Testing Program - Yield        Wynne
# 2616  2013      LEW  ATP  Advanced Testing Program - Yield        Wynne
# 2617  2013      RMT  ATP  Advanced Testing Program - Yield        Wynne
# 2619  2014      LEW  ATP  Advanced Testing Program - Yield        Wynne
# 2620  2014      RMT  ATP  Advanced Testing Program - Yield        Wynne
# 2622  2015      LEW  ATP  Advanced Testing Program - Yield        Wynne
# 2623  2015      RMT  ATP  Advanced Testing Program - Yield        Wynne
# 2624  2016      LEW  ATP  Advanced Testing Program - Yield        Wynne
# 2625  2016      RMT  ATP  Advanced Testing Program - Yield        Wynne
# 2627  2017      LEW  ATP  Advanced Testing Program - Yield        Wynne
# 2628  2017      RMT  ATP  Advanced Testing Program - Yield        Wynne
# 2630  2018      LEW  ATP  Advanced Testing Program - Yield        Wynne
# 2631  2018      RMT  ATP  Advanced Testing Program - Yield        Wynne
#
#       Plot_Yield  Yield
# 15          11.7   3529
# 16           6.6   2004
# 18          13.6   4114
# 19          17.1   5159
# 21          12.8   3873
# 22          10.9   3306
# 24          12.5   3774
# 25          12.5   3781
# 27          16.3   4926
# 28          12.1   3660
# 30          14.4   4342
# 31          11.8   3582
# 32           8.5   2586
# 33           7.5   2262
# 35          16.0   4841
# 36          14.8   4480
# 38          12.9   3915
# 39          13.6   4104
# 41          15.0   4539
# 42          12.6   3801
# 44          16.1   4885
# 45          12.0   3638
# 47          17.8   5396
# 48          10.4   3159
# 50          14.6   4408
# 51          17.4   5257
# 52           8.0   2415
# 53          11.4   3436
# 55          17.4   5272
# 56          16.6   5012
# ...          ...    ...
# 2557        11.9   3592
# 2558        11.0   3320
# 2560        14.9   4511
# 2561        10.6   3214
# 2563        13.9   4191
# 2564        16.0   4850
# 2565         6.7   2035
# 2566        13.0   3919
# 2568        13.2   3980
# 2569        16.0   4836
# 2571        18.6   5614
# 2572        14.3   4338
# 2607        10.2   3099
# 2608         6.5   1966
# 2610        14.5   4394
# 2611        17.3   5235
# 2613        12.7   3849
# 2614         9.0   2734
# 2616        10.8   3275
# 2617         9.2   2798
# 2619        17.2   5203
# 2620        11.5   3478
# 2622        15.9   4814
# 2623        19.2   5795
# 2624        10.1   3044
# 2625         9.7   2934
# 2627        17.6   5320
# 2628        20.2   6102
# 2630        17.3   5244
# 2631        14.4   4370
#
# [96 rows x 7 columns]

# %% [markdown]
# 12. Export the means of each line by location to an excel file called 'NCSU_release.xlsx'

# %%
#line_data[]peanut_yield[(peanut_yield['Year'] == 2017)]['Yield'].mean()
#by_line = line_data.groupby('NC_Accession')
#by_line.mean()
#by_line_loc = line_data.groupby(['NC_Accession','Location'])
#by_line_loc.mean()
NCSU_release = line_data.groupby(['NC_Accession','Location']).mean()
NCSU_release.to_excel('NCSU_release.xlsx')
